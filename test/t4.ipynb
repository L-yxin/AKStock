# %%
import KLineForm as klf

# %%
for i in dir(klf.buy):
    func = getattr(klf.buy, i)
    if callable(func):
        if hasattr(func, '__message__'):
            print(i, func.__message__)
# Out:
# is_bullish_candle_dominant N周期阳线占优
# is_bullish_engulfing 看涨吞没
# is_bullish_engulfing_enhanced 阳包阴加强
# is_bullish_ma_arrangement 均线多头排列
# is_gap_up 跳空上扬
# is_healthy_pullback 回调缩量上涨放量
# is_macd_golden_cross MACD金叉
# is_macd_second_golden_cross MACD零上二次金叉
# is_morning_star 早晨之星
# is_moving_average_up 均线向上
# is_one_barrier_three_lines 一阳穿三线
# is_piercing 曙光初现
# is_small_bullish_steps 底部连续小阳推升
# is_three_white_soldiers 红三兵
# is_two_crows_one_white 多方炮
# is_volume_price_sync N周期量价同步走强
# ma_golden_cross 均线金叉
