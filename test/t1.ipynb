# %%
from mootdx.reader import Reader

# %%
reader = Reader.factory(market='std', tdxdir='D:\\Users\\lyx\\Desktop\\hsjday')

# %%
df = reader.daily(symbol='sh563900')
# Out:
# 2026-04-06 16:35:21,316 - tdxpy - ERROR - Unknown security type !
# NoneType: None
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df = reader.daily(symbol='sh563900')
#
# File ~\.conda\envs\akStock_python12\Lib\site-packages\mootdx\reader.py:102, in StdReader.daily(self, symbol, **kwargs)
#      99 reader = MooTdxDailyBarReader()
#     100 vipdoc = self.find_path(symbol=symbol, subdir='lday', suffix='day')
# --> 102 result = reader.get_df(str(vipdoc)) if vipdoc else None
#     103 return to_data(result, symbol=symbol, **kwargs)
#
# File ~\.conda\envs\akStock_python12\Lib\site-packages\tdxpy\reader\daily_bar_reader.py:95, in TdxDailyBarReader.get_df(self, code_or_file, exchange)
#      88 """
#      89
#      90 :param code_or_file:
#      91 :param exchange:
#      92 :return:
#      93 """
#      94 if not exchange:
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
